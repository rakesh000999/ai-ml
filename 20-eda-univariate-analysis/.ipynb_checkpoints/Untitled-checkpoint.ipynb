# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\rakesh\anaconda3\envs\new-ml\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 439          440         0       2  Kvillner, Mr. Johan Henrik Johannesson
# 189          190         0       3                     Turcin, Mr. Stjepan
# 804          805         1       3                 Hedman, Mr. Oskar Arvid
# 102          103         0       1               White, Mr. Richard Frasar
# 597          598         0       3                     Johnson, Mr. Alfred
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 439  male  31.0      0      0  C.A. 18723  10.5000   NaN        S
# 189  male  36.0      0      0      349247   7.8958   NaN        S
# 804  male  27.0      0      0      347089   6.9750   NaN        S
# 102  male  21.0      0      1       35281  77.2875   D26        S
# 597  male  49.0      0      0        LINE   0.0000   NaN        S

# %% [markdown]
# ## 1. Categorical Data

# %% [markdown]
# ### a. Countplot

# %%
sns.countplot(df, x='Survived', hue='Survived')
df['Survived'].value_counts()
# df['Survived'].value_counts().plot(kind='bar')
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# sns.countplot(df, x='Sex')
# sns.countplot(df, x='Sex', hue='Pclass')
sns.countplot(df, x='Embarked', hue='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ### b. PieChart

# %%
# df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Numerical Data

# %% [markdown]
# ### a. Histogram

# %%
# plt.hist(df['Age'])
plt.hist(df['Age'], bins=10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### b. Distplot

# %%
sns.distplot(df['Age'])
sns.displot(df['Age'])
# Out:
# C:\Users\rakesh\AppData\Local\Temp\ipykernel_13056\4115203331.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %% [markdown]
# ### c. Boxplot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)
