# %%
import pandas as pd
import requests

# %%
# requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=eyJhbGciOiJIUzI1NiJ9/language=en-US&page=1')

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMzMxODA2N2I2MTJkNTdlODI1OGZkNGIzMDUyMDJjZSIsIm5iZiI6MTcyMjY2NDc5Ni45MTEsInN1YiI6IjY2YWRjNzVjZmM0YWRmMGNmY2EzNDYzOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.cUk2X4T2tLXm1qtjVKcOfoTU_z_JaS5B-delbFDeal8"
}

response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 31.7251,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.715,
#   'vote_count': 29610},
#  {'adult': False,
#   'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     31.7251
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     29.1345
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     18.6137
# 3  The true story of how businessman Oskar Schind...   1993-12-15     16.8532
# 4  The defense and the prosecution have rested an...   1957-04-10     11.8048
#
#    vote_average  vote_count
# 0         8.715       29610
# 1         8.687       22366
# 2         8.570       13529
# 3         8.600       17042
# 4         8.552        9692

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
all_dfs = []

# %%
for i in range(1,429):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMzMxODA2N2I2MTJkNTdlODI1OGZkNGIzMDUyMDJjZSIsIm5iZiI6MTcyMjY2NDc5Ni45MTEsInN1YiI6IjY2YWRjNzVjZmM0YWRmMGNmY2EzNDYzOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.cUk2X4T2tLXm1qtjVKcOfoTU_z_JaS5B-delbFDeal8"
    }

    response = requests.get(url, headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
    all_dfs.append(temp_df)

# %%
df = pd.concat(all_dfs, ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555   14372                 Leviathan
# 8556   12500            American Ninja
# 8557   11078         National Security
# 8558    1410                 Dark Star
# 8559  866346       The Retirement Plan
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
